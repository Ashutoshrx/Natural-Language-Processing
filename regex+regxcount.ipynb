# %%
import regex,re
import nltk, pprint
from urllib.request import urlopen
print("hello")
# Out:
# hello

# %%
url = open("C:\\assignment-1.txt","r",encoding="utf8")
file = url.read()
print(file)
# Out:
# “I hope, my dear,” said Mr. Bennet to his wife, as they were at breakfast the next morning, “that you have ordered a good dinner to-day, because I have reason to expect an addition to our family party.”
#
# “Who do you mean, my dear? I know of nobody that is coming, I am sure, unless Charlotte Lucas should happen to call in—and I hope my dinners are good enough for her. I do not believe she often sees such at home.”
#
# “The person of whom I speak is a gentleman, and a stranger.”
#
# Mrs. Bennet’s eyes sparkled. “A gentleman and a stranger! It is Mr. Bingley, I am sure! Well, I am sure I shall be extremely glad to see Mr. Bingley. But—good Lord! how unlucky! There is not a bit of fish to be got to-day. Lydia, my love, ring the bell—I must speak to Hill this moment.”
#
# “It is not Mr. Bingley,” said her husband; “it is a person whom I never saw in the whole course of my life.”
#
# ...

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\dell\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
tokens = nltk.word_tokenize(file)
#print(word_tokenize(file))

# %%
text = nltk.Text(tokens)

# %%
print(re.findall('Mr\.\s\w+', file))
# Out:
# ['Mr. Bennet', 'Mr. Bingley', 'Mr. Bingley', 'Mr. Bingley', 'Mr. Collins', 'Mr. Bennet', 'Mr. Collins']

# %%
print(re.findall('Mrs\.\s\w+', file))
# Out:
# ['Mrs. Bennet', 'Mrs. Bennet']

# %%
print(re.findall('\w+ion', file))
# Out:
# ['addition', 'question', 'attention', 'mention']

# %%
print(re.findall('\w+ous\s', file))
# Out:
# ['odious ', 'iniquitous ']

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\dell\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
from nltk.corpus import stopwords 
en_stops = set(stopwords.words('english'))

for word in file: 
    if word not in en_stops:
        
        print(word)
# Out:
# “
# I
#
# h
# p
# e
# ,
#
#
# e
# r
# ,
# ”
#
#
# M
# r
# .
#
# B
# e
# n
# n
# e
#
#
# h
#
# w
# f
# e
# ,
#
#
# h
# e
#
# w
# e
# r
# e
#
#
# b
# r
# e
# k
# f
#
# h
# e
#
# n
# e
# x
#
# r
# n
# n
# g
# ,
#
# “
# h
#
# u
#
# h
# v
# e
#
# r
# e
# r
# e
#
#
# g
#
# n
# n
# e
# r
#
# -
# ,
#
# b
# e
# c
# u
# e
#
# I
#
# h
# v
# e
#
# r
# e
# n
#
#
# e
# x
# p
# e
# c
#
# n
#
# n
#
#
# u
# r
#
# f
# l
#
# p
# r
# .
# ”
#
#
#
#
# “
# W
# h
#
#
# u
#
# e
# n
# ,
#
#
# e
# r
# ?
#
# I
#
# k
# n
# w
#
# f
#
# n
# b
#
# h
#
#
# c
# n
# g
# ,
#
# I
#
#
# u
# r
# e
# ,
#
# u
# n
# l
# e
#
# C
# h
# r
# l
# e
#
# L
# u
# c
#
# h
# u
# l
#
# h
# p
# p
# e
# n
#
#
# c
# l
# l
#
# n
# —
# n
#
# I
#
# h
# p
# e
#
#
# n
# n
# e
# r
#
# r
# e
#
# g
#
# e
# n
# u
# g
# h
#
# f
# r
#
# h
# e
# r
# .
#
# I
#
#
# n
#
# b
# e
# l
# e
# v
# e
#
# h
# e
#
# f
# e
# n
#
# e
# e
#
# u
# c
# h
#
#
# h
# e
# .
# ”
#
#
#
#
# “
# T
# h
# e
#
# p
# e
# r
# n
#
# f
#
# w
# h
#
# I
#
# p
# e
# k
#
#
#
# g
# e
# ...

# %%
b= filtered_document[:50]
print(b)
# Out:
# ['“', 'I', 'hope', ',', 'dear', ',', '”', 'said', 'Mr.', 'Bennet', 'wife', ',', 'breakfast', 'next', 'morning', ',', '“', 'ordered', 'good', 'dinner', 'to-day', ',', 'I', 'reason', 'expect', 'addition', 'family', 'party.', '”', '“', 'Who', 'mean', ',', 'dear', '?', 'I', 'know', 'nobody', 'coming', ',', 'I', 'sure', ',', 'unless', 'Charlotte', 'Lucas', 'happen', 'call', 'in—and', 'I']
